# %%
import pandas as pd

# %%
cities = pd.read_csv('Resources/cities.csv')

# %%
print(cities)
# Out:
#               City      Lat       Lon  Max Temp  Humidity  Cloudiness  \
# 0       Bredasdorp -34.5322   20.0403     49.06        92          93
# 1      Thunder Bay  48.4001  -89.3168     76.91        41          20
# 2       The Valley  18.2170  -63.0578     86.14        66          40
# 3             Tefé  -3.3542  -64.7114     84.31        74          75
# 4            Sitka  57.0531 -135.3300     60.69        77         100
# ..             ...      ...       ...       ...       ...         ...
# 565  Fuerte Olimpo -21.0415  -57.8738     78.10        56          61
# 566          Boden  65.8252   21.6886     62.60        89          69
# 567      Stornoway  58.2093   -6.3865     52.93        83          20
# 568          Yatou  37.1500  122.3833     77.81        96           4
# 569       Qui Nhon  13.7667  109.2333     79.75        80         100
#
#      Wind Speed Country        Date
# 0          5.93      ZA  1659645944
# 1          6.91      CA  1659645944
# ...

# %%
cities.to_html('../cities_table.html')

# %%
print(data_HTML)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lon</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Bredasdorp</td>
#       <td>-34.5322</td>
#       <td>20.0403</td>
#       <td>49.06</td>
#       <td>92</td>
#       <td>93</td>
#       <td>5.93</td>
#       <td>ZA</td>
#       <td>1659645944</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Thunder Bay</td>
#       <td>48.4001</td>
#       <td>-89.3168</td>
#       <td>76.91</td>
#       <td>41</td>
#       <td>20</td>
#       <td>6.91</td>
#       <td>CA</td>
#       <td>1659645944</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>The Valley</td>
#       <td>18.2170</td>
#       <td>-63.0578</td>
# ...
